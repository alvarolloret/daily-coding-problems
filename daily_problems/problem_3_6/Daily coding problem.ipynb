# %% [markdown]
# ## Question 3

# %% [markdown]
# This problem was asked by Uber.
#
# Given an array of integers, return a new array such that each element at index i of the new array is the product of all the numbers in the original array except the one at i.
#
# For example, if our input was [1, 2, 3, 4, 5], the expected output would be [120, 60, 40, 30, 24]. If our input was [3, 2, 1], the expected output would be [2, 3, 6].
#
# Follow-up: what if you can't use division?

# %%
input_list = [1, 2, 3, 4, 5]
expected_solution = [120, 60, 40, 30, 24]

# %% [markdown]
# ### Solution  (Didn't have time to finish it)

# %%
'''
from functools import reduce

# A function to add two numbers
def multiply(a, b):
    return a * b if a != x else a


# Using reduce to sum all elements in the list
result = [reduce(multiply, input) for x in input_list]
print(result)
'''
# Out:
# '\nfrom functools import reduce\n\n# A function to add two numbers\ndef multiply(a, b):\n    return a * b if a != x else a\n\n\n# Using reduce to sum all elements in the list\nresult = [reduce(multiply, input) for x in input_list]\nprint(result)\n'

# %% [markdown]
# ### Proposed by Ian
# (problem, it doesn't work if there is the same number in the list)

# %%
from functools import reduce
input = [1, 2, 3, 4, 5]

solution = [reduce(lambda a,v:a*v if v != x else a,input) for x in input]
solution_solved = [reduce(lambda a, b: a * b, input[i+1:] +input[:i]) for i, v in enumerate(input)]
solution_solved
# Out:
# [120, 60, 40, 30, 24]

# %% [markdown]
# ### Proposed by ChatGpt

# %% [markdown]
# Sure, here's the solution to the problem:
#
# ### Solution using division:
#
# 1. Calculate the total product of all elements in the input array.
# 2. Iterate through the array and for each element at index `i`, divide the total product by the element at index `i` to get the product excluding that element.
#
# Here is the Python code implementing the solution using division:
#
# ```python
# def product_except_self(nums):
#     total_product = 1
#     for num in nums:
#         total_product *= num
#
#     result = [total_product // num for num in nums]
#     return result
#
# # Test cases
# input1 = [1, 2, 3, 4, 5]
# input2 = [3, 2, 1]
#
# print(product_except_self(input1))  # Output: [120, 60, 40, 30, 24]
# print(product_except_self(input2))  # Output: [2, 3, 6]
# ```
#
# ### Solution without using division:
#
# Without using division, you can solve this problem by calculating the products of the left and right sides of each element separately, excluding the element itself. Then, multiply these left and right products to get the final result.
#
# Here's the Python code implementing the solution without using division:
#
# ```python
# def product_except_self(nums):
#     length = len(nums)
#     left_products = [1] * length
#     right_products = [1] * length
#     result = [1] * length
#
#     # Calculate left products
#     for i in range(1, length):
#         left_products[i] = left_products[i - 1] * nums[i - 1]
#
#     # Calculate right products
#     for i in range(length - 2, -1, -1):
#         right_products[i] = right_products[i + 1] * nums[i + 1]
#
#     # Multiply left and right products to get the final result
#     for i in range(length):
#         result[i] = left_products[i] * right_products[i]
#
#     return result
#
# # Test cases
# input1 = [1, 2, 3, 4, 5]
# input2 = [3, 2, 1]
#
# print(product_except_self(input1))  # Output: [120, 60, 40, 30, 24]
# print(product_except_self(input2))  # Output: [2, 3, 6]
# ```
#
# This solution has a time complexity of O(n), where n is the length of the input array, since it traverses the array multiple times to calculate the left and right products.

# %% [markdown]
# # Question 3 bis

# %% [markdown]
# Good morning! Here's your coding interview problem for today.
#
# This problem was asked by Google.
#
# Given the root to a binary tree, implement serialize(root), which serializes the tree into a string, and deserialize(s), which deserializes the string back into the tree.
#
# For example, given the following Node class
# ```
# class Node:
#     def __init__(self, val, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
#
#
# ```
#
# The following test should pass:
# ```
# node = Node('root', Node('left', Node('left.left')), Node('right'))
# assert deserialize(serialize(node)).left.left.val == 'left.left'
# ```

# %% [markdown]
# ### My solution
#
# Only worked p

# %%
import re
"""
           root
      left       right
left.left


"""



class Node:
    def __init__(self, val, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right


def serialize(value: str | Node)->str:
    if type(value)== type(None):
        return "0"
    if type(value)== str:
      return value
    elif  type(value) == type(Node("")):
      return "(" + serialize(value.left) +'<' + serialize(value.val) +'>' + serialize(value.right) +")"

def deserialize(value: str) -> Node:
    if type(value) == Node:
      return value
    if type(value) == str:
      left_item =  re.findall(r'\((.*?)\)', value[1:-2])
      right_item = re.findall(r'\((.*?)\)'r'\((.*?)\)', value)

node = Node('root', Node('left', Node('left.left')), Node('right', right="right"))
serialize(node)
# Out:
# '(((0<left.left>0)<left>0)<root>(0<right>right))'

# %% [markdown]
# ### Solution chat gpt

# %%
"DIDNT WORK"
# Out:
# 'DIDNT WORK'

# %% [markdown]
# # Question 4

# %% [markdown]
# Good morning! Here's your coding interview problem for today.
#
# This problem was asked by Stripe.
#
# Given an array of integers, find the first missing positive integer in linear time and constant space. In other words, find the lowest positive integer that does not exist in the array. The array can contain duplicates and negative numbers as well.
#
# For example, the input [3, 4, -1, 1] should give 2. The input [1, 2, 0] should give 3.
#
# You can modify the input array in-place.
# **bold text**
#
# ### My solution

# %%
from functools import reduce
input_1  = [3, 4, -1, 1]
result_1 = 2

input_2 = [1,2,0]
result_2 = 3
# Out:
# 1

# %%
result=sorted(input_2)
print(result)
reduce(lambda a,b:  a if (a>0 and a<=b) else  b,result) +1
# Out:
# [0, 1, 2]
# 2

# %% [markdown]
# # Qüestion 5

# %% [markdown]
# cons(a, b) constructs a pair, and car(pair) and cdr(pair) returns the first and last element of that pair. For example, car(cons(3, 4)) returns 3, and cdr(cons(3, 4)) returns 4.
#
# Given this implementation of cons:
#
# def cons(a, b):
#     def pair(f):
#         return f(a, b)
#     return pair
# Implement car and cdr.

# %%
def cons(a, b):
    def pair(f):
        return f(a, b)
    return pair

def cdr(pair):
  def first(a,b):
      return a
  return pair(first)

def car(pair):
  return pair(lambda a,b: a)

# %%
cons(3,4)
# Out:
# <function __main__.cons.<locals>.pair(f)>

# %%
print(car(cons(3, 4)))
# Out:
# 3

# %% [markdown]
# # Question 6

# %% [markdown]
# This problem was asked by Google.
#
# An XOR linked list is a more memory efficient doubly linked list. Instead of each node holding next and prev fields, it holds a field named both, which is an XOR of the next node and the previous node. Implement an XOR linked list; it has an add(element) which adds the element to the end, and a get(index) which returns the node at index.
#
# If using a language that has no pointers (such as Python), you can assume you have access to get_pointer and dereference_pointer functions that converts between nodes and memory addresses.

# %%
class Xor:
  listed = []
  def add(self, element):
      self.listed.append(element)
  def get(self, index):
      return self.listed[index]
